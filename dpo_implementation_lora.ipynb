# %%
import pandas as pd
import unidecode
from tqdm.notebook import tqdm

import torch

torch.cuda.empty_cache()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')


from transformers import T5ForConditionalGeneration, T5Tokenizer, TrainingArguments, AutoTokenizer
from peft import LoraConfig, PeftModel, get_peft_model, TaskType
from transformers import BitsAndBytesConfig
from trl import DPOTrainer
from datasets import Dataset

from utils import remove_diacritics

model_name = "google/flan-t5-small"
LORA_RUN = True

model_output_dir = f"dpo_{model_name}" 
model_output_dir += "_lora" if LORA_RUN else ""
print(f"{model_output_dir=}")
# Out:
# WARNING:tensorflow:From d:\Python310\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# model_output_dir='dpo_google/flan-t5-small_lora'

# %%
df = pd.read_csv("data/t5-small.csv")

df['chosen'] = df['translations'].apply(remove_diacritics)
df["sentence"] = df["sentence"].apply(lambda x: f"translate English to Romanian: {x}")
df = df.rename(columns={"translations": "rejected", "sentence": "prompt"})
train_dataset = Dataset.from_dict({col: df[col].values.tolist() for col in df.columns})
df
# Out:
#                                                   prompt  \
# 0       translate English to Romanian: I ate the cheese.
# 1        translate English to Romanian: Today is Monday.
# 2      translate English to Romanian: Does he speak E...
# 3      translate English to Romanian: I'm sort of tired.
# 4      translate English to Romanian: I am indebted t...
# ...                                                  ...
# 15801  translate English to Romanian: It would be a d...
# 15802  translate English to Romanian: I ate a burdock...
# 15803  translate English to Romanian: You say you've ...
# 15804  translate English to Romanian: It's a good sen...
# 15805  translate English to Romanian: I wouldn't want...
#
#                                        rejected  \
# 0                             Am mâncat brânza.
# 1                     Astăzi este ziua de luni.
# 2                    Vorbeşte el limba engleză?
# 3                          Sunt oarecum obosit.
# 4                      Sunt îndatorat acestuia.
# ...                                         ...
# 15801                 Ar fi o sarcină dificilă.
# 15802  Am mâncat o tempura de rădăcini burdice.
# 15803              Aţi spus că aţi văzut o UFO?
# 15804                Oricum, este o frază bună.
# 15805              Nu aş dori să fiu judecător.
#
#                                          chosen
# 0                             Am mancat branza.
# 1                     Astazi este ziua de luni.
# 2                    Vorbeste el limba engleza?
# 3                          Sunt oarecum obosit.
# 4                      Sunt indatorat acestuia.
# ...                                         ...
# 15801                 Ar fi o sarcina dificila.
# 15802  Am mancat o tempura de radacini burdice.
# 15803              Ati spus ca ati vazut o UFO?
# 15804                Oricum, este o fraza buna.
# 15805              Nu as dori sa fiu judecator.
#
# [15806 rows x 3 columns]

# %%
peft_config = LoraConfig(
    r=16,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type=TaskType.SEQ_2_SEQ_LM,
    target_modules=["q", "v"]
)

# %%
model_name = 'google/flan-t5-base'  # Replace with your model
model = T5ForConditionalGeneration.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    load_in_4bit=True)

ref_model = T5ForConditionalGeneration.from_pretrained(
    model_name,
    torch_dtype=torch.float16,
    load_in_4bit=True)


tokenizer = T5Tokenizer.from_pretrained(model_name)
# Out:
# bin d:\Python310\lib\site-packages\bitsandbytes\libbitsandbytes_cuda121.dll
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thouroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
# # This is an experiment where the base layers are frozen

# for name, param in model.named_parameters():
#     if 'lm_head' not in name:
#         param.requires_grad = False

# %%
training_args = TrainingArguments(
    per_device_train_batch_size=16,
    gradient_accumulation_steps=1,
    learning_rate=1e-4,
    lr_scheduler_type="cosine",
    # max_steps=200,
    save_strategy="epoch",
    logging_steps=1,
    output_dir=model_output_dir,
    optim="paged_adamw_32bit",
    warmup_steps=100,
    bf16=True,
    report_to="tensorboard",
    num_train_epochs=1
)

# Create DPO trainer
dpo_trainer = DPOTrainer(
    model,
    ref_model,
    args=training_args,
    train_dataset=train_dataset,
    tokenizer=tokenizer,
    peft_config=peft_config,
    beta=0.1,
    max_prompt_length=128,
    max_length=1536,
)
# Out:
# d:\Python310\lib\site-packages\trl\trainer\dpo_trainer.py:300: UserWarning: When using DPODataCollatorWithPadding with an encoder decoder architecture, you should set `max_target_length` in the DPOTrainer's init it will be set to `128` by default, but you should do it yourself in the future.
#   warnings.warn(
# d:\Python310\lib\site-packages\trl\trainer\dpo_trainer.py:316: UserWarning: When using DPODataCollatorWithPadding, you should set `remove_unused_columns=False` in your TrainingArguments we have set it for you, but you should do it yourself in the future.
#   warnings.warn(
# Map:   0%|          | 0/15806 [00:00<?, ? examples/s]

# %%
dpo_trainer.train()
# Out:
# You are using 8-bit optimizers with a version of `bitsandbytes` < 0.41.1. It is recommended to update your version as a major bug has been fixed in 8-bit optimizers.
#   0%|          | 0/988 [00:00<?, ?it/s]
# d:\Python310\lib\site-packages\bitsandbytes\nn\modules.py:224: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(f'Input type into Linear4bit is torch.float16, but bnb_4bit_compute_type=torch.float32 (default). This will lead to slow inference or training speed.')
# Could not estimate the number of tokens of the input, floating-point operations will not be computed
# {'loss': 0.6362, 'learning_rate': 1.0000000000000002e-06, 'rewards/chosen': 0.012895585969090462, 'rewards/rejected': -0.11120486259460449, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.1241004467010498, 'logps/rejected': -24.24505615234375, 'logps/chosen': -45.456939697265625, 'logits/rejected': -13.785174369812012, 'logits/chosen': -13.29578971862793, 'epoch': 0.0}
# {'loss': 0.6735, 'learning_rate': 2.0000000000000003e-06, 'rewards/chosen': -0.05146024376153946, 'rewards/rejected': -0.11063986271619797, 'rewards/accuracies': 0.625, 'rewards/margins': 0.05917961895465851, 'logps/rejected': -20.114412307739258, 'logps/chosen': -50.49498748779297, 'logits/rejected': -14.09111499786377, 'logits/chosen': -13.873868942260742, 'epoch': 0.0}
# {'loss': 0.6571, 'learning_rate': 3e-06, 'rewards/chosen': -0.0031595472246408463, 'rewards/rejected': -0.0955241322517395, 'rewards/accuracies': 0.625, 'rewards/margins': 0.09236457943916321, 'logps/rejected': -16.260791778564453, 'logps/chosen': -40.754249572753906, 'logits/rejected': -13.138885498046875, 'logits/chosen': -12.802069664001465, 'epoch': 0.0}
# {'loss': 0.6916, 'learning_rate': 4.000000000000001e-06, 'rewards/chosen': -0.042345065623521805, 'rewards/rejected': -0.05220365524291992, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.009858585894107819, 'logps/rejected': -23.18441390991211, 'logps/chosen': -42.75335693359375, 'logits/rejected': -13.302618026733398, 'logits/chosen': -13.21982479095459, 'epoch': 0.0}
# {'loss': 0.6932, 'learning_rate': 5e-06, 'rewards/chosen': -0.08098285645246506, 'rewards/rejected': -0.09315559267997742, 'rewards/accuracies': 0.5, 'rewards/margins': 0.012172732502222061, 'logps/rejected': -19.643054962158203, 'logps/chosen': -40.00471496582031, 'logits/rejected': -12.712904930114746, 'logits/chosen': -12.266115188598633, 'epoch': 0.01}
# {'loss': 0.6845, 'learning_rate': 6e-06, 'rewards/chosen': -0.06593146175146103, 'rewards/rejected': -0.08970576524734497, 'rewards/accuracies': 0.625, 'rewards/margins': 0.02377431094646454, 'logps/rejected': -20.952072143554688, 'logps/chosen': -32.226646423339844, 'logits/rejected': -13.169061660766602, 'logits/chosen': -13.255526542663574, 'epoch': 0.01}
# {'loss': 0.6981, 'learning_rate': 7.000000000000001e-06, 'rewards/chosen': -0.0587632842361927, 'rewards/rejected': -0.05718233436346054, 'rewards/accuracies': 0.375, 'rewards/margins': -0.001580953598022461, 'logps/rejected': -21.17571258544922, 'logps/chosen': -35.387386322021484, 'logits/rejected': -13.307493209838867, 'logits/chosen': -13.048908233642578, 'epoch': 0.01}
# {'loss': 0.6736, 'learning_rate': 8.000000000000001e-06, 'rewards/chosen': -0.012672150507569313, 'rewards/rejected': -0.05838661268353462, 'rewards/accuracies': 0.625, 'rewards/margins': 0.04571445286273956, 'logps/rejected': -16.91122055053711, 'logps/chosen': -38.58108139038086, 'logits/rejected': -13.857834815979004, 'logits/chosen': -13.5997314453125, 'epoch': 0.01}
# {'loss': 0.6737, 'learning_rate': 9e-06, 'rewards/chosen': -0.03358004242181778, 'rewards/rejected': -0.09059323370456696, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.057013191282749176, 'logps/rejected': -17.002729415893555, 'logps/chosen': -36.75239562988281, 'logits/rejected': -13.663727760314941, 'logits/chosen': -13.430886268615723, 'epoch': 0.01}
# {'loss': 0.6459, 'learning_rate': 1e-05, 'rewards/chosen': -0.03801846504211426, 'rewards/rejected': -0.14787983894348145, 'rewards/accuracies': 0.625, 'rewards/margins': 0.10986137390136719, 'logps/rejected': -16.662776947021484, 'logps/chosen': -37.70744705200195, 'logits/rejected': -13.662668228149414, 'logits/chosen': -13.259146690368652, 'epoch': 0.01}
# {'loss': 0.6812, 'learning_rate': 1.1000000000000001e-05, 'rewards/chosen': -0.06343099474906921, 'rewards/rejected': -0.0958576649427414, 'rewards/accuracies': 0.625, 'rewards/margins': 0.03242667019367218, 'logps/rejected': -23.894412994384766, 'logps/chosen': -43.978965759277344, 'logits/rejected': -13.332265853881836, 'logits/chosen': -13.196752548217773, 'epoch': 0.01}
# {'loss': 0.7667, 'learning_rate': 1.2e-05, 'rewards/chosen': -0.20804327726364136, 'rewards/rejected': -0.08888168632984161, 'rewards/accuracies': 0.5, 'rewards/margins': -0.11916156858205795, 'logps/rejected': -26.70827865600586, 'logps/chosen': -51.57368469238281, 'logits/rejected': -13.218865394592285, 'logits/chosen': -13.066120147705078, 'epoch': 0.01}
# {'loss': 0.7027, 'learning_rate': 1.3000000000000001e-05, 'rewards/chosen': -0.07862842828035355, 'rewards/rejected': -0.06415028125047684, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.014478136785328388, 'logps/rejected': -19.013418197631836, 'logps/chosen': -33.79307556152344, 'logits/rejected': -13.260754585266113, 'logits/chosen': -13.145731925964355, 'epoch': 0.01}
# {'loss': 0.6833, 'learning_rate': 1.4000000000000001e-05, 'rewards/chosen': -0.08898316323757172, 'rewards/rejected': -0.11607539653778076, 'rewards/accuracies': 0.5, 'rewards/margins': 0.027092233300209045, 'logps/rejected': -18.005210876464844, 'logps/chosen': -36.8157958984375, 'logits/rejected': -13.83330249786377, 'logits/chosen': -13.523229598999023, 'epoch': 0.01}
# {'loss': 0.6839, 'learning_rate': 1.5e-05, 'rewards/chosen': -0.08905752748250961, 'rewards/rejected': -0.1143299788236618, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.02527245506644249, 'logps/rejected': -18.26422119140625, 'logps/chosen': -37.516971588134766, 'logits/rejected': -12.931208610534668, 'logits/chosen': -12.917081832885742, 'epoch': 0.02}
# {'loss': 0.6535, 'learning_rate': 1.6000000000000003e-05, 'rewards/chosen': -0.0299668125808239, 'rewards/rejected': -0.11396829783916473, 'rewards/accuracies': 0.625, 'rewards/margins': 0.08400148898363113, 'logps/rejected': -19.84661865234375, 'logps/chosen': -35.29457473754883, 'logits/rejected': -12.87840747833252, 'logits/chosen': -12.739237785339355, 'epoch': 0.02}
# {'loss': 0.6806, 'learning_rate': 1.7000000000000003e-05, 'rewards/chosen': -0.04532219097018242, 'rewards/rejected': -0.07679110020399094, 'rewards/accuracies': 0.375, 'rewards/margins': 0.03146890550851822, 'logps/rejected': -18.870262145996094, 'logps/chosen': -37.77406692504883, 'logits/rejected': -13.188891410827637, 'logits/chosen': -13.0709228515625, 'epoch': 0.02}
# {'loss': 0.672, 'learning_rate': 1.8e-05, 'rewards/chosen': -0.011354941874742508, 'rewards/rejected': -0.058487847447395325, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.04713290184736252, 'logps/rejected': -14.128053665161133, 'logps/chosen': -32.467315673828125, 'logits/rejected': -13.278063774108887, 'logits/chosen': -13.298397064208984, 'epoch': 0.02}
# {'loss': 0.6986, 'learning_rate': 1.9e-05, 'rewards/chosen': -0.09464554488658905, 'rewards/rejected': -0.0926024466753006, 'rewards/accuracies': 0.5625, 'rewards/margins': -0.0020430991426110268, 'logps/rejected': -16.80342674255371, 'logps/chosen': -32.070762634277344, 'logits/rejected': -13.96628189086914, 'logits/chosen': -13.679129600524902, 'epoch': 0.02}
# {'loss': 0.6786, 'learning_rate': 2e-05, 'rewards/chosen': -0.08012130111455917, 'rewards/rejected': -0.11518697440624237, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.03506568446755409, 'logps/rejected': -19.692955017089844, 'logps/chosen': -36.09180450439453, 'logits/rejected': -13.422555923461914, 'logits/chosen': -13.108177185058594, 'epoch': 0.02}
# {'loss': 0.6826, 'learning_rate': 2.1e-05, 'rewards/chosen': -0.0521688349545002, 'rewards/rejected': -0.08108683675527573, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.028918005526065826, 'logps/rejected': -19.037532806396484, 'logps/chosen': -32.98460388183594, 'logits/rejected': -13.446788787841797, 'logits/chosen': -13.16804027557373, 'epoch': 0.02}
# {'loss': 0.6846, 'learning_rate': 2.2000000000000003e-05, 'rewards/chosen': -0.0044168345630168915, 'rewards/rejected': -0.02569534257054329, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.021278508007526398, 'logps/rejected': -15.965350151062012, 'logps/chosen': -41.87708282470703, 'logits/rejected': -13.240340232849121, 'logits/chosen': -12.887626647949219, 'epoch': 0.02}
# {'loss': 0.7113, 'learning_rate': 2.3000000000000003e-05, 'rewards/chosen': -0.07516442239284515, 'rewards/rejected': -0.04550471156835556, 'rewards/accuracies': 0.5, 'rewards/margins': -0.029659707099199295, 'logps/rejected': -11.801040649414062, 'logps/chosen': -25.321182250976562, 'logits/rejected': -14.443984031677246, 'logits/chosen': -14.19676685333252, 'epoch': 0.02}
# {'loss': 0.6455, 'learning_rate': 2.4e-05, 'rewards/chosen': 0.017072882503271103, 'rewards/rejected': -0.08689319342374802, 'rewards/accuracies': 0.75, 'rewards/margins': 0.10396607965230942, 'logps/rejected': -18.423675537109375, 'logps/chosen': -32.96818161010742, 'logits/rejected': -13.240954399108887, 'logits/chosen': -13.095250129699707, 'epoch': 0.02}
# {'loss': 0.7039, 'learning_rate': 2.5e-05, 'rewards/chosen': -0.08991365134716034, 'rewards/rejected': -0.07870824635028839, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.011205404065549374, 'logps/rejected': -25.412548065185547, 'logps/chosen': -48.05613327026367, 'logits/rejected': -13.690162658691406, 'logits/chosen': -13.273490905761719, 'epoch': 0.03}
# {'loss': 0.6472, 'learning_rate': 2.6000000000000002e-05, 'rewards/chosen': 0.007099992595613003, 'rewards/rejected': -0.0935710147023201, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.10067100822925568, 'logps/rejected': -16.606586456298828, 'logps/chosen': -32.37623596191406, 'logits/rejected': -13.630083084106445, 'logits/chosen': -13.403078079223633, 'epoch': 0.03}
# {'loss': 0.7224, 'learning_rate': 2.7000000000000002e-05, 'rewards/chosen': -0.16833534836769104, 'rewards/rejected': -0.12288037687540054, 'rewards/accuracies': 0.5, 'rewards/margins': -0.04545498639345169, 'logps/rejected': -19.11553192138672, 'logps/chosen': -35.09185028076172, 'logits/rejected': -13.261855125427246, 'logits/chosen': -12.782118797302246, 'epoch': 0.03}
# {'loss': 0.6928, 'learning_rate': 2.8000000000000003e-05, 'rewards/chosen': -0.11773638427257538, 'rewards/rejected': -0.1300126314163208, 'rewards/accuracies': 0.5, 'rewards/margins': 0.012276243418455124, 'logps/rejected': -14.951005935668945, 'logps/chosen': -26.324527740478516, 'logits/rejected': -13.734601974487305, 'logits/chosen': -13.754382133483887, 'epoch': 0.03}
# {'loss': 0.6727, 'learning_rate': 2.9e-05, 'rewards/chosen': -0.07521990686655045, 'rewards/rejected': -0.12694962322711945, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.0517297089099884, 'logps/rejected': -16.357769012451172, 'logps/chosen': -26.73404312133789, 'logits/rejected': -13.343283653259277, 'logits/chosen': -13.007329940795898, 'epoch': 0.03}
# {'loss': 0.6731, 'learning_rate': 3e-05, 'rewards/chosen': -0.07500656694173813, 'rewards/rejected': -0.12318724393844604, 'rewards/accuracies': 0.5, 'rewards/margins': 0.04818069189786911, 'logps/rejected': -22.200313568115234, 'logps/chosen': -42.257484436035156, 'logits/rejected': -12.689538955688477, 'logits/chosen': -12.5839262008667, 'epoch': 0.03}
# {'loss': 0.7259, 'learning_rate': 3.1e-05, 'rewards/chosen': -0.11571735143661499, 'rewards/rejected': -0.070977121591568, 'rewards/accuracies': 0.625, 'rewards/margins': -0.0447402223944664, 'logps/rejected': -17.960277557373047, 'logps/chosen': -48.104217529296875, 'logits/rejected': -13.584661483764648, 'logits/chosen': -13.137016296386719, 'epoch': 0.03}
# {'loss': 0.6376, 'learning_rate': 3.2000000000000005e-05, 'rewards/chosen': -0.004836099222302437, 'rewards/rejected': -0.12640738487243652, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.12157128006219864, 'logps/rejected': -22.125335693359375, 'logps/chosen': -38.52021026611328, 'logits/rejected': -13.883618354797363, 'logits/chosen': -13.430656433105469, 'epoch': 0.03}
# {'loss': 0.7073, 'learning_rate': 3.3e-05, 'rewards/chosen': -0.12539522349834442, 'rewards/rejected': -0.10350043326616287, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.021894793957471848, 'logps/rejected': -14.952566146850586, 'logps/chosen': -31.319780349731445, 'logits/rejected': -13.459094047546387, 'logits/chosen': -13.22382640838623, 'epoch': 0.03}
# {'loss': 0.6902, 'learning_rate': 3.4000000000000007e-05, 'rewards/chosen': -0.08431640267372131, 'rewards/rejected': -0.09834855794906616, 'rewards/accuracies': 0.375, 'rewards/margins': 0.014032160863280296, 'logps/rejected': -20.54834747314453, 'logps/chosen': -33.898033142089844, 'logits/rejected': -13.55620288848877, 'logits/chosen': -13.373381614685059, 'epoch': 0.03}
# {'loss': 0.6513, 'learning_rate': 3.5e-05, 'rewards/chosen': 0.007571150548756123, 'rewards/rejected': -0.08809078484773636, 'rewards/accuracies': 0.75, 'rewards/margins': 0.0956619381904602, 'logps/rejected': -19.503854751586914, 'logps/chosen': -40.28242492675781, 'logits/rejected': -13.441388130187988, 'logits/chosen': -12.988933563232422, 'epoch': 0.04}
# {'loss': 0.7064, 'learning_rate': 3.6e-05, 'rewards/chosen': -0.11608032137155533, 'rewards/rejected': -0.10707791149616241, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.009002409875392914, 'logps/rejected': -21.23944091796875, 'logps/chosen': -38.75206756591797, 'logits/rejected': -13.430885314941406, 'logits/chosen': -12.79033088684082, 'epoch': 0.04}
# {'loss': 0.6505, 'learning_rate': 3.7e-05, 'rewards/chosen': 0.004237514920532703, 'rewards/rejected': -0.08950597047805786, 'rewards/accuracies': 0.75, 'rewards/margins': 0.09374348819255829, 'logps/rejected': -23.14491081237793, 'logps/chosen': -38.63003921508789, 'logits/rejected': -13.592336654663086, 'logits/chosen': -13.300697326660156, 'epoch': 0.04}
# {'loss': 0.7044, 'learning_rate': 3.8e-05, 'rewards/chosen': -0.07332532107830048, 'rewards/rejected': -0.0606372207403183, 'rewards/accuracies': 0.5, 'rewards/margins': -0.012688091024756432, 'logps/rejected': -19.87181854248047, 'logps/chosen': -39.20896911621094, 'logits/rejected': -14.33134651184082, 'logits/chosen': -13.665650367736816, 'epoch': 0.04}
# {'loss': 0.679, 'learning_rate': 3.9000000000000006e-05, 'rewards/chosen': -0.05024094879627228, 'rewards/rejected': -0.09133695811033249, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.041095998138189316, 'logps/rejected': -19.19964027404785, 'logps/chosen': -31.492586135864258, 'logits/rejected': -13.437867164611816, 'logits/chosen': -13.10598373413086, 'epoch': 0.04}
# {'loss': 0.6746, 'learning_rate': 4e-05, 'rewards/chosen': -0.05138617381453514, 'rewards/rejected': -0.09628389775753021, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.04489772021770477, 'logps/rejected': -12.59679126739502, 'logps/chosen': -25.543994903564453, 'logits/rejected': -13.926736831665039, 'logits/chosen': -13.569796562194824, 'epoch': 0.04}
# {'loss': 0.6578, 'learning_rate': 4.1e-05, 'rewards/chosen': 0.02284717932343483, 'rewards/rejected': -0.052571654319763184, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.07541883736848831, 'logps/rejected': -16.4070987701416, 'logps/chosen': -31.70510482788086, 'logits/rejected': -13.840883255004883, 'logits/chosen': -13.577553749084473, 'epoch': 0.04}
# {'loss': 0.6646, 'learning_rate': 4.2e-05, 'rewards/chosen': -0.03304542973637581, 'rewards/rejected': -0.09950976818799973, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.06646434217691422, 'logps/rejected': -14.601985931396484, 'logps/chosen': -25.583972930908203, 'logits/rejected': -13.46363353729248, 'logits/chosen': -13.180096626281738, 'epoch': 0.04}
# {'loss': 0.6843, 'learning_rate': 4.3e-05, 'rewards/chosen': 0.003465117886662483, 'rewards/rejected': -0.029445145279169083, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.03291025757789612, 'logps/rejected': -18.413772583007812, 'logps/chosen': -32.76850128173828, 'logits/rejected': -13.307674407958984, 'logits/chosen': -12.97330379486084, 'epoch': 0.04}
# {'loss': 0.6875, 'learning_rate': 4.4000000000000006e-05, 'rewards/chosen': -0.007000453770160675, 'rewards/rejected': -0.030720192939043045, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.02371973730623722, 'logps/rejected': -12.189447402954102, 'logps/chosen': -29.542816162109375, 'logits/rejected': -13.96682071685791, 'logits/chosen': -13.711129188537598, 'epoch': 0.04}
# {'loss': 0.687, 'learning_rate': 4.5e-05, 'rewards/chosen': -0.0556296743452549, 'rewards/rejected': -0.07666321098804474, 'rewards/accuracies': 0.6875, 'rewards/margins': 0.021033544093370438, 'logps/rejected': -21.821853637695312, 'logps/chosen': -40.117828369140625, 'logits/rejected': -12.841365814208984, 'logits/chosen': -12.527181625366211, 'epoch': 0.05}
# {'loss': 0.6767, 'learning_rate': 4.600000000000001e-05, 'rewards/chosen': -0.04942351579666138, 'rewards/rejected': -0.08906646072864532, 'rewards/accuracies': 0.625, 'rewards/margins': 0.03964294120669365, 'logps/rejected': -19.70524787902832, 'logps/chosen': -40.21910858154297, 'logits/rejected': -13.381633758544922, 'logits/chosen': -12.91135025024414, 'epoch': 0.05}
# {'loss': 0.6366, 'learning_rate': 4.7e-05, 'rewards/chosen': 0.006685702130198479, 'rewards/rejected': -0.11838644742965698, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.1250721514225006, 'logps/rejected': -17.141592025756836, 'logps/chosen': -28.380924224853516, 'logits/rejected': -13.393864631652832, 'logits/chosen': -13.126142501831055, 'epoch': 0.05}
# {'loss': 0.6608, 'learning_rate': 4.8e-05, 'rewards/chosen': -0.024510815739631653, 'rewards/rejected': -0.09515547752380371, 'rewards/accuracies': 0.75, 'rewards/margins': 0.07064466178417206, 'logps/rejected': -18.71700668334961, 'logps/chosen': -35.09049987792969, 'logits/rejected': -13.539021492004395, 'logits/chosen': -13.444208145141602, 'epoch': 0.05}
# {'loss': 0.6866, 'learning_rate': 4.9e-05, 'rewards/chosen': -0.07253029942512512, 'rewards/rejected': -0.09714159369468689, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.02461128681898117, 'logps/rejected': -25.564373016357422, 'logps/chosen': -48.829776763916016, 'logits/rejected': -13.179187774658203, 'logits/chosen': -12.986715316772461, 'epoch': 0.05}
# {'loss': 0.7084, 'learning_rate': 5e-05, 'rewards/chosen': -0.09197439253330231, 'rewards/rejected': -0.08078793436288834, 'rewards/accuracies': 0.5, 'rewards/margins': -0.011186458170413971, 'logps/rejected': -24.933616638183594, 'logps/chosen': -48.208011627197266, 'logits/rejected': -13.236987113952637, 'logits/chosen': -12.732550621032715, 'epoch': 0.05}
# {'loss': 0.6899, 'learning_rate': 5.1000000000000006e-05, 'rewards/chosen': -0.08776804059743881, 'rewards/rejected': -0.105475515127182, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.017707470804452896, 'logps/rejected': -22.48995590209961, 'logps/chosen': -43.353904724121094, 'logits/rejected': -13.57397174835205, 'logits/chosen': -13.272058486938477, 'epoch': 0.05}
# {'loss': 0.68, 'learning_rate': 5.2000000000000004e-05, 'rewards/chosen': -0.11186005175113678, 'rewards/rejected': -0.14579500257968903, 'rewards/accuracies': 0.5, 'rewards/margins': 0.03393494710326195, 'logps/rejected': -14.08658218383789, 'logps/chosen': -33.15496063232422, 'logits/rejected': -14.017511367797852, 'logits/chosen': -13.56951904296875, 'epoch': 0.05}
# {'loss': 0.6628, 'learning_rate': 5.300000000000001e-05, 'rewards/chosen': -0.01236681453883648, 'rewards/rejected': -0.08673480153083801, 'rewards/accuracies': 0.625, 'rewards/margins': 0.07436797767877579, 'logps/rejected': -23.380481719970703, 'logps/chosen': -37.912841796875, 'logits/rejected': -13.63109016418457, 'logits/chosen': -13.376959800720215, 'epoch': 0.05}
# {'loss': 0.7152, 'learning_rate': 5.4000000000000005e-05, 'rewards/chosen': -0.06728976964950562, 'rewards/rejected': -0.03479234501719475, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.03249742090702057, 'logps/rejected': -16.24979019165039, 'logps/chosen': -38.347694396972656, 'logits/rejected': -13.749360084533691, 'logits/chosen': -13.528331756591797, 'epoch': 0.05}
# {'loss': 0.6535, 'learning_rate': 5.500000000000001e-05, 'rewards/chosen': -0.030767489224672318, 'rewards/rejected': -0.12166211009025574, 'rewards/accuracies': 0.625, 'rewards/margins': 0.09089462459087372, 'logps/rejected': -21.067031860351562, 'logps/chosen': -40.41659164428711, 'logits/rejected': -13.486420631408691, 'logits/chosen': -13.189292907714844, 'epoch': 0.06}
# {'loss': 0.7006, 'learning_rate': 5.6000000000000006e-05, 'rewards/chosen': -0.08810475468635559, 'rewards/rejected': -0.08305956423282623, 'rewards/accuracies': 0.625, 'rewards/margins': -0.0050451792776584625, 'logps/rejected': -14.833455085754395, 'logps/chosen': -35.922271728515625, 'logits/rejected': -13.622693061828613, 'logits/chosen': -13.360261917114258, 'epoch': 0.06}
# {'loss': 0.6659, 'learning_rate': 5.6999999999999996e-05, 'rewards/chosen': -0.038204289972782135, 'rewards/rejected': -0.10637585818767548, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.06817156076431274, 'logps/rejected': -19.38199806213379, 'logps/chosen': -37.25914001464844, 'logits/rejected': -13.240509986877441, 'logits/chosen': -12.963034629821777, 'epoch': 0.06}
# {'loss': 0.6852, 'learning_rate': 5.8e-05, 'rewards/chosen': -0.08340867608785629, 'rewards/rejected': -0.11070037633180618, 'rewards/accuracies': 0.5, 'rewards/margins': 0.027291689068078995, 'logps/rejected': -21.365516662597656, 'logps/chosen': -35.31800079345703, 'logits/rejected': -13.30269718170166, 'logits/chosen': -13.068499565124512, 'epoch': 0.06}
# {'loss': 0.6557, 'learning_rate': 5.9e-05, 'rewards/chosen': 0.013754703104496002, 'rewards/rejected': -0.08158758282661438, 'rewards/accuracies': 0.625, 'rewards/margins': 0.09534228593111038, 'logps/rejected': -20.618331909179688, 'logps/chosen': -45.611202239990234, 'logits/rejected': -13.438036918640137, 'logits/chosen': -12.973006248474121, 'epoch': 0.06}
# {'loss': 0.6807, 'learning_rate': 6e-05, 'rewards/chosen': -0.06806120276451111, 'rewards/rejected': -0.1031574010848999, 'rewards/accuracies': 0.4375, 'rewards/margins': 0.03509620204567909, 'logps/rejected': -17.96393394470215, 'logps/chosen': -39.49938201904297, 'logits/rejected': -13.865765571594238, 'logits/chosen': -13.566743850708008, 'epoch': 0.06}
# {'loss': 0.6633, 'learning_rate': 6.1e-05, 'rewards/chosen': -0.023003049194812775, 'rewards/rejected': -0.08945174515247345, 'rewards/accuracies': 0.625, 'rewards/margins': 0.06644868850708008, 'logps/rejected': -17.69950294494629, 'logps/chosen': -38.379302978515625, 'logits/rejected': -13.342693328857422, 'logits/chosen': -13.18882942199707, 'epoch': 0.06}
# {'loss': 0.7012, 'learning_rate': 6.2e-05, 'rewards/chosen': -0.06846342980861664, 'rewards/rejected': -0.060868266969919205, 'rewards/accuracies': 0.4375, 'rewards/margins': -0.007595159579068422, 'logps/rejected': -18.123672485351562, 'logps/chosen': -31.56331443786621, 'logits/rejected': -13.50841236114502, 'logits/chosen': -13.652352333068848, 'epoch': 0.06}
# {'loss': 0.6509, 'learning_rate': 6.3e-05, 'rewards/chosen': 0.035486724227666855, 'rewards/rejected': -0.055301256477832794, 'rewards/accuracies': 0.75, 'rewards/margins': 0.09078799188137054, 'logps/rejected': -15.61186408996582, 'logps/chosen': -29.466670989990234, 'logits/rejected': -13.5020751953125, 'logits/chosen': -13.431405067443848, 'epoch': 0.06}
# {'loss': 0.6615, 'learning_rate': 6.400000000000001e-05, 'rewards/chosen': -0.02139117941260338, 'rewards/rejected': -0.09274432808160782, 'rewards/accuracies': 0.625, 'rewards/margins': 0.07135315239429474, 'logps/rejected': -18.245494842529297, 'logps/chosen': -34.19452667236328, 'logits/rejected': -14.104634284973145, 'logits/chosen': -13.79030704498291, 'epoch': 0.06}
# {'loss': 0.6788, 'learning_rate': 6.500000000000001e-05, 'rewards/chosen': -0.05268530920147896, 'rewards/rejected': -0.08746911585330963, 'rewards/accuracies': 0.625, 'rewards/margins': 0.034783802926540375, 'logps/rejected': -15.566731452941895, 'logps/chosen': -30.951984405517578, 'logits/rejected': -13.255942344665527, 'logits/chosen': -13.222219467163086, 'epoch': 0.07}
# {'loss': 0.6245, 'learning_rate': 6.6e-05, 'rewards/chosen': 0.04866582155227661, 'rewards/rejected': -0.09867739677429199, 'rewards/accuracies': 0.75, 'rewards/margins': 0.1473432183265686, 'logps/rejected': -26.297019958496094, 'logps/chosen': -40.11220169067383, 'logits/rejected': -12.869000434875488, 'logits/chosen': -12.861053466796875, 'epoch': 0.07}
# {'loss': 0.6634, 'learning_rate': 6.7e-05, 'rewards/chosen': -0.0031807152554392815, 'rewards/rejected': -0.07878262549638748, 'rewards/accuracies': 0.5, 'rewards/margins': 0.07560190558433533, 'logps/rejected': -20.459043502807617, 'logps/chosen': -37.49009704589844, 'logits/rejected': -13.512706756591797, 'logits/chosen': -13.237034797668457, 'epoch': 0.07}
# {'loss': 0.6024, 'learning_rate': 6.800000000000001e-05, 'rewards/chosen': 0.06963382661342621, 'rewards/rejected': -0.13729393482208252, 'rewards/accuracies': 0.875, 'rewards/margins': 0.20692776143550873, 'logps/rejected': -20.449264526367188, 'logps/chosen': -44.575111389160156, 'logits/rejected': -13.726907730102539, 'logits/chosen': -13.009976387023926, 'epoch': 0.07}
# {'loss': 0.6628, 'learning_rate': 6.9e-05, 'rewards/chosen': -0.03766974061727524, 'rewards/rejected': -0.11325738579034805, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.07558763772249222, 'logps/rejected': -16.005168914794922, 'logps/chosen': -27.21152114868164, 'logits/rejected': -12.82905101776123, 'logits/chosen': -12.918806076049805, 'epoch': 0.07}
# {'loss': 0.6738, 'learning_rate': 7e-05, 'rewards/chosen': -0.02331816963851452, 'rewards/rejected': -0.0664622113108635, 'rewards/accuracies': 0.75, 'rewards/margins': 0.04314403980970383, 'logps/rejected': -16.922821044921875, 'logps/chosen': -33.342491149902344, 'logits/rejected': -12.905622482299805, 'logits/chosen': -12.84197998046875, 'epoch': 0.07}
# {'loss': 0.6559, 'learning_rate': 7.1e-05, 'rewards/chosen': 0.002614472061395645, 'rewards/rejected': -0.08136391639709473, 'rewards/accuracies': 0.75, 'rewards/margins': 0.08397838473320007, 'logps/rejected': -24.44375991821289, 'logps/chosen': -43.738861083984375, 'logits/rejected': -13.121837615966797, 'logits/chosen': -13.06574821472168, 'epoch': 0.07}
# {'loss': 0.6249, 'learning_rate': 7.2e-05, 'rewards/chosen': 0.007118205539882183, 'rewards/rejected': -0.17082500457763672, 'rewards/accuracies': 0.625, 'rewards/margins': 0.17794319987297058, 'logps/rejected': -25.131406784057617, 'logps/chosen': -42.32829284667969, 'logits/rejected': -12.816712379455566, 'logits/chosen': -12.480907440185547, 'epoch': 0.07}
# {'loss': 0.6531, 'learning_rate': 7.3e-05, 'rewards/chosen': 0.05305718258023262, 'rewards/rejected': -0.038017552345991135, 'rewards/accuracies': 0.75, 'rewards/margins': 0.09107473492622375, 'logps/rejected': -20.98061180114746, 'logps/chosen': -38.96810531616211, 'logits/rejected': -12.739124298095703, 'logits/chosen': -12.603686332702637, 'epoch': 0.07}
# {'loss': 0.6395, 'learning_rate': 7.4e-05, 'rewards/chosen': 0.05918069928884506, 'rewards/rejected': -0.07173769176006317, 'rewards/accuracies': 0.875, 'rewards/margins': 0.13091838359832764, 'logps/rejected': -19.3638916015625, 'logps/chosen': -35.667877197265625, 'logits/rejected': -14.276095390319824, 'logits/chosen': -13.811300277709961, 'epoch': 0.07}
# {'loss': 0.6361, 'learning_rate': 7.500000000000001e-05, 'rewards/chosen': 0.02727213129401207, 'rewards/rejected': -0.10185596346855164, 'rewards/accuracies': 0.75, 'rewards/margins': 0.129128098487854, 'logps/rejected': -15.45185661315918, 'logps/chosen': -30.6441593170166, 'logits/rejected': -13.105025291442871, 'logits/chosen': -12.980411529541016, 'epoch': 0.08}
# {'loss': 0.6054, 'learning_rate': 7.6e-05, 'rewards/chosen': 0.08774536848068237, 'rewards/rejected': -0.10515790432691574, 'rewards/accuracies': 0.75, 'rewards/margins': 0.19290326535701752, 'logps/rejected': -18.00353240966797, 'logps/chosen': -42.36811065673828, 'logits/rejected': -13.027604103088379, 'logits/chosen': -12.57949161529541, 'epoch': 0.08}
# {'loss': 0.6174, 'learning_rate': 7.7e-05, 'rewards/chosen': 0.08604005724191666, 'rewards/rejected': -0.08603772521018982, 'rewards/accuracies': 0.75, 'rewards/margins': 0.17207777500152588, 'logps/rejected': -16.614582061767578, 'logps/chosen': -36.39842987060547, 'logits/rejected': -13.444987297058105, 'logits/chosen': -13.166993141174316, 'epoch': 0.08}
# {'loss': 0.6595, 'learning_rate': 7.800000000000001e-05, 'rewards/chosen': -0.049022529274225235, 'rewards/rejected': -0.1353147327899933, 'rewards/accuracies': 0.625, 'rewards/margins': 0.08629220724105835, 'logps/rejected': -19.933307647705078, 'logps/chosen': -29.931642532348633, 'logits/rejected': -12.889991760253906, 'logits/chosen': -12.686527252197266, 'epoch': 0.08}
# {'loss': 0.6346, 'learning_rate': 7.900000000000001e-05, 'rewards/chosen': 0.007324211299419403, 'rewards/rejected': -0.12798094749450684, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.13530516624450684, 'logps/rejected': -23.597614288330078, 'logps/chosen': -39.121299743652344, 'logits/rejected': -13.229125022888184, 'logits/chosen': -12.963285446166992, 'epoch': 0.08}
# {'loss': 0.6236, 'learning_rate': 8e-05, 'rewards/chosen': 0.04926903173327446, 'rewards/rejected': -0.10998889803886414, 'rewards/accuracies': 0.5625, 'rewards/margins': 0.1592579185962677, 'logps/rejected': -17.333221435546875, 'logps/chosen': -34.09434509277344, 'logits/rejected': -13.072491645812988, 'logits/chosen': -12.95175552368164, 'epoch': 0.08}
# {'loss': 0.615, 'learning_rate': 8.1e-05, 'rewards/chosen': 0.0488760843873024, 'rewards/rejected': -0.12633869051933289, 'rewards/accuracies': 0.875, 'rewards/margins': 0.1752147674560547, 'logps/rejected': -14.16007137298584, 'logps/chosen': -26.40883445739746, 'logits/rejected': -13.349464416503906, 'logits/chosen': -13.148223876953125, 'epoch': 0.08}
# {'loss': 0.6434, 'learning_rate': 8.2e-05, 'rewards/chosen': 0.0055876225233078, 'rewards/rejected': -0.10498204827308655, 'rewards/accuracies': 0.625, 'rewards/margins': 0.11056967079639435, 'logps/rejected': -24.922264099121094, 'logps/chosen': -35.39916229248047, 'logits/rejected': -12.440786361694336, 'logits/chosen': -12.160062789916992, 'epoch': 0.08}
# {'loss': 0.5906, 'learning_rate': 8.3e-05, 'rewards/chosen': 0.10150998830795288, 'rewards/rejected': -0.1402050256729126, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.24171501398086548, 'logps/rejected': -23.43206787109375, 'logps/chosen': -38.782188415527344, 'logits/rejected': -12.884431838989258, 'logits/chosen': -12.550616264343262, 'epoch': 0.08}
# {'loss': 0.5861, 'learning_rate': 8.4e-05, 'rewards/chosen': 0.0452529639005661, 'rewards/rejected': -0.21474939584732056, 'rewards/accuracies': 0.875, 'rewards/margins': 0.26000237464904785, 'logps/rejected': -27.224288940429688, 'logps/chosen': -40.32417297363281, 'logits/rejected': -12.705648422241211, 'logits/chosen': -12.707524299621582, 'epoch': 0.09}
# {'loss': 0.5896, 'learning_rate': 8.5e-05, 'rewards/chosen': 0.10299792885780334, 'rewards/rejected': -0.13298901915550232, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.23598694801330566, 'logps/rejected': -16.514001846313477, 'logps/chosen': -32.13737487792969, 'logits/rejected': -13.017682075500488, 'logits/chosen': -12.934629440307617, 'epoch': 0.09}
# {'loss': 0.5733, 'learning_rate': 8.6e-05, 'rewards/chosen': 0.13595348596572876, 'rewards/rejected': -0.13811728358268738, 'rewards/accuracies': 0.9375, 'rewards/margins': 0.27407076954841614, 'logps/rejected': -19.373374938964844, 'logps/chosen': -37.29973602294922, 'logits/rejected': -13.214849472045898, 'logits/chosen': -13.05908203125, 'epoch': 0.09}
# {'loss': 0.572, 'learning_rate': 8.7e-05, 'rewards/chosen': 0.08265219628810883, 'rewards/rejected': -0.19205619394779205, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.2747083902359009, 'logps/rejected': -15.452573776245117, 'logps/chosen': -26.391326904296875, 'logits/rejected': -13.02231216430664, 'logits/chosen': -12.80128288269043, 'epoch': 0.09}
# {'loss': 0.5322, 'learning_rate': 8.800000000000001e-05, 'rewards/chosen': 0.1804017275571823, 'rewards/rejected': -0.20871327817440033, 'rewards/accuracies': 1.0, 'rewards/margins': 0.38911500573158264, 'logps/rejected': -21.92306900024414, 'logps/chosen': -37.51618957519531, 'logits/rejected': -13.004788398742676, 'logits/chosen': -12.747297286987305, 'epoch': 0.09}
# {'loss': 0.5895, 'learning_rate': 8.900000000000001e-05, 'rewards/chosen': 0.057617515325546265, 'rewards/rejected': -0.179826021194458, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.23744353652000427, 'logps/rejected': -16.633127212524414, 'logps/chosen': -30.692516326904297, 'logits/rejected': -13.095527648925781, 'logits/chosen': -12.678214073181152, 'epoch': 0.09}
# {'loss': 0.5999, 'learning_rate': 9e-05, 'rewards/chosen': 0.048983052372932434, 'rewards/rejected': -0.15583692491054535, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.20481997728347778, 'logps/rejected': -17.608352661132812, 'logps/chosen': -25.548473358154297, 'logits/rejected': -13.041961669921875, 'logits/chosen': -12.82644271850586, 'epoch': 0.09}
# {'loss': 0.5645, 'learning_rate': 9.1e-05, 'rewards/chosen': 0.08982576429843903, 'rewards/rejected': -0.21049140393733978, 'rewards/accuracies': 0.9375, 'rewards/margins': 0.3003171384334564, 'logps/rejected': -19.193124771118164, 'logps/chosen': -35.107383728027344, 'logits/rejected': -12.43160343170166, 'logits/chosen': -12.19255542755127, 'epoch': 0.09}
# {'loss': 0.579, 'learning_rate': 9.200000000000001e-05, 'rewards/chosen': 0.030601881444454193, 'rewards/rejected': -0.24497324228286743, 'rewards/accuracies': 0.875, 'rewards/margins': 0.2755751311779022, 'logps/rejected': -23.660049438476562, 'logps/chosen': -35.823646545410156, 'logits/rejected': -12.090553283691406, 'logits/chosen': -12.15138053894043, 'epoch': 0.09}
# {'loss': 0.6058, 'learning_rate': 9.300000000000001e-05, 'rewards/chosen': 0.03438887745141983, 'rewards/rejected': -0.16967155039310455, 'rewards/accuracies': 0.75, 'rewards/margins': 0.2040604203939438, 'logps/rejected': -10.176448822021484, 'logps/chosen': -25.545974731445312, 'logits/rejected': -13.341448783874512, 'logits/chosen': -12.973593711853027, 'epoch': 0.09}
# {'loss': 0.5398, 'learning_rate': 9.4e-05, 'rewards/chosen': 0.10141461342573166, 'rewards/rejected': -0.25403541326522827, 'rewards/accuracies': 1.0, 'rewards/margins': 0.3554500341415405, 'logps/rejected': -15.918346405029297, 'logps/chosen': -29.268455505371094, 'logits/rejected': -12.882560729980469, 'logits/chosen': -12.707232475280762, 'epoch': 0.1}
# {'loss': 0.4993, 'learning_rate': 9.5e-05, 'rewards/chosen': 0.19408638775348663, 'rewards/rejected': -0.30189451575279236, 'rewards/accuracies': 0.875, 'rewards/margins': 0.4959809184074402, 'logps/rejected': -31.88199806213379, 'logps/chosen': -49.170249938964844, 'logits/rejected': -12.59778118133545, 'logits/chosen': -12.411150932312012, 'epoch': 0.1}
# {'loss': 0.5417, 'learning_rate': 9.6e-05, 'rewards/chosen': 0.09868583083152771, 'rewards/rejected': -0.2661893367767334, 'rewards/accuracies': 0.875, 'rewards/margins': 0.3648751676082611, 'logps/rejected': -27.085363388061523, 'logps/chosen': -36.511566162109375, 'logits/rejected': -12.22880744934082, 'logits/chosen': -12.034040451049805, 'epoch': 0.1}
# {'loss': 0.4799, 'learning_rate': 9.7e-05, 'rewards/chosen': 0.22842265665531158, 'rewards/rejected': -0.3365839123725891, 'rewards/accuracies': 1.0, 'rewards/margins': 0.5650065541267395, 'logps/rejected': -25.949188232421875, 'logps/chosen': -47.74927520751953, 'logits/rejected': -12.787463188171387, 'logits/chosen': -12.49761962890625, 'epoch': 0.1}
# {'loss': 0.5612, 'learning_rate': 9.8e-05, 'rewards/chosen': 0.06633171439170837, 'rewards/rejected': -0.24852728843688965, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.314859002828598, 'logps/rejected': -15.133435249328613, 'logps/chosen': -27.565099716186523, 'logits/rejected': -12.290177345275879, 'logits/chosen': -12.280142784118652, 'epoch': 0.1}
# {'loss': 0.4689, 'learning_rate': 9.900000000000001e-05, 'rewards/chosen': 0.20314475893974304, 'rewards/rejected': -0.3497236967086792, 'rewards/accuracies': 0.875, 'rewards/margins': 0.5528684258460999, 'logps/rejected': -21.549989700317383, 'logps/chosen': -36.60735321044922, 'logits/rejected': -12.47856616973877, 'logits/chosen': -12.186867713928223, 'epoch': 0.1}
# {'loss': 0.5188, 'learning_rate': 0.0001, 'rewards/chosen': 0.05346601828932762, 'rewards/rejected': -0.387964129447937, 'rewards/accuracies': 0.875, 'rewards/margins': 0.44143015146255493, 'logps/rejected': -18.55590057373047, 'logps/chosen': -32.6119270324707, 'logits/rejected': -12.326833724975586, 'logits/chosen': -12.05429744720459, 'epoch': 0.1}
# {'loss': 0.582, 'learning_rate': 9.999968709437562e-05, 'rewards/chosen': 0.05032661557197571, 'rewards/rejected': -0.20623303949832916, 'rewards/accuracies': 0.9375, 'rewards/margins': 0.2565596401691437, 'logps/rejected': -23.49561309814453, 'logps/chosen': -32.66851043701172, 'logits/rejected': -11.783617973327637, 'logits/chosen': -11.576431274414062, 'epoch': 0.1}
# {'loss': 0.5293, 'learning_rate': 9.999874838141888e-05, 'rewards/chosen': 0.016230331733822823, 'rewards/rejected': -0.4323427975177765, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.44857311248779297, 'logps/rejected': -24.74825096130371, 'logps/chosen': -36.086463928222656, 'logits/rejected': -12.364227294921875, 'logits/chosen': -11.967954635620117, 'epoch': 0.1}
# {'loss': 0.4974, 'learning_rate': 9.99971838728789e-05, 'rewards/chosen': 0.09125954657793045, 'rewards/rejected': -0.410092294216156, 'rewards/accuracies': 0.875, 'rewards/margins': 0.5013518333435059, 'logps/rejected': -24.316272735595703, 'logps/chosen': -35.45367431640625, 'logits/rejected': -12.207179069519043, 'logits/chosen': -12.095804214477539, 'epoch': 0.1}
# {'loss': 0.5209, 'learning_rate': 9.999499358833745e-05, 'rewards/chosen': 0.06652789562940598, 'rewards/rejected': -0.37100446224212646, 'rewards/accuracies': 0.875, 'rewards/margins': 0.43753230571746826, 'logps/rejected': -28.52147674560547, 'logps/chosen': -40.19649887084961, 'logits/rejected': -11.980122566223145, 'logits/chosen': -11.622029304504395, 'epoch': 0.11}
# {'loss': 0.4422, 'learning_rate': 9.99921775552086e-05, 'rewards/chosen': 0.10382071882486343, 'rewards/rejected': -0.5853239893913269, 'rewards/accuracies': 0.875, 'rewards/margins': 0.6891447305679321, 'logps/rejected': -25.745058059692383, 'logps/chosen': -38.406558990478516, 'logits/rejected': -12.027475357055664, 'logits/chosen': -11.818819046020508, 'epoch': 0.11}
# {'loss': 0.4349, 'learning_rate': 9.998873580873848e-05, 'rewards/chosen': 0.12539589405059814, 'rewards/rejected': -0.529871940612793, 'rewards/accuracies': 0.9375, 'rewards/margins': 0.6552677750587463, 'logps/rejected': -22.022212982177734, 'logps/chosen': -36.30284118652344, 'logits/rejected': -12.016057968139648, 'logits/chosen': -11.819727897644043, 'epoch': 0.11}
# {'loss': 0.4976, 'learning_rate': 9.998466839200473e-05, 'rewards/chosen': 0.029971420764923096, 'rewards/rejected': -0.47355443239212036, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.5035258531570435, 'logps/rejected': -15.611446380615234, 'logps/chosen': -24.371906280517578, 'logits/rejected': -12.166749954223633, 'logits/chosen': -12.013029098510742, 'epoch': 0.11}
# {'loss': 0.4804, 'learning_rate': 9.99799753559161e-05, 'rewards/chosen': -0.0986301451921463, 'rewards/rejected': -0.7064036130905151, 'rewards/accuracies': 0.75, 'rewards/margins': 0.6077734231948853, 'logps/rejected': -25.402931213378906, 'logps/chosen': -38.529518127441406, 'logits/rejected': -12.701318740844727, 'logits/chosen': -12.410934448242188, 'epoch': 0.11}
# {'loss': 0.4206, 'learning_rate': 9.997465675921163e-05, 'rewards/chosen': 0.08249922841787338, 'rewards/rejected': -0.6603452563285828, 'rewards/accuracies': 1.0, 'rewards/margins': 0.7428444623947144, 'logps/rejected': -28.7376766204834, 'logps/chosen': -44.342437744140625, 'logits/rejected': -12.509505271911621, 'logits/chosen': -12.332777976989746, 'epoch': 0.11}
# {'loss': 0.4916, 'learning_rate': 9.996871266846011e-05, 'rewards/chosen': -0.09540247917175293, 'rewards/rejected': -0.5936762690544128, 'rewards/accuracies': 0.875, 'rewards/margins': 0.4982737898826599, 'logps/rejected': -23.10089683532715, 'logps/chosen': -32.95652389526367, 'logits/rejected': -11.987532615661621, 'logits/chosen': -11.9061279296875, 'epoch': 0.11}
# {'loss': 0.4368, 'learning_rate': 9.99621431580591e-05, 'rewards/chosen': -0.013692431151866913, 'rewards/rejected': -0.7769056558609009, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.7632132172584534, 'logps/rejected': -27.845359802246094, 'logps/chosen': -41.84185791015625, 'logits/rejected': -12.79405689239502, 'logits/chosen': -12.628241539001465, 'epoch': 0.11}
# {'loss': 0.5125, 'learning_rate': 9.995494831023409e-05, 'rewards/chosen': -0.06737825274467468, 'rewards/rejected': -0.5433151125907898, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.4759368598461151, 'logps/rejected': -21.78985023498535, 'logps/chosen': -28.39537811279297, 'logits/rejected': -12.351537704467773, 'logits/chosen': -12.177371978759766, 'epoch': 0.11}
# {'loss': 0.431, 'learning_rate': 9.994712821503738e-05, 'rewards/chosen': -0.07437866926193237, 'rewards/rejected': -0.7677902579307556, 'rewards/accuracies': 1.0, 'rewards/margins': 0.6934115886688232, 'logps/rejected': -26.277650833129883, 'logps/chosen': -33.12309646606445, 'logits/rejected': -12.598264694213867, 'logits/chosen': -12.402538299560547, 'epoch': 0.11}
# {'loss': 0.3799, 'learning_rate': 9.993868297034707e-05, 'rewards/chosen': -0.04233222454786301, 'rewards/rejected': -1.026812195777893, 'rewards/accuracies': 0.875, 'rewards/margins': 0.9844799637794495, 'logps/rejected': -27.00455093383789, 'logps/chosen': -44.49175262451172, 'logits/rejected': -12.16018009185791, 'logits/chosen': -11.92758846282959, 'epoch': 0.12}
# {'loss': 0.4376, 'learning_rate': 9.992961268186573e-05, 'rewards/chosen': -0.07609961926937103, 'rewards/rejected': -0.8988982439041138, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.8227986693382263, 'logps/rejected': -27.30655288696289, 'logps/chosen': -45.91883850097656, 'logits/rejected': -12.057392120361328, 'logits/chosen': -11.641404151916504, 'epoch': 0.12}
# {'loss': 0.427, 'learning_rate': 9.991991746311917e-05, 'rewards/chosen': 0.024739157408475876, 'rewards/rejected': -0.6986389756202698, 'rewards/accuracies': 0.875, 'rewards/margins': 0.7233781814575195, 'logps/rejected': -24.308792114257812, 'logps/chosen': -34.3897705078125, 'logits/rejected': -12.547626495361328, 'logits/chosen': -12.246228218078613, 'epoch': 0.12}
# {'loss': 0.3327, 'learning_rate': 9.990959743545486e-05, 'rewards/chosen': 0.014454476535320282, 'rewards/rejected': -1.0312855243682861, 'rewards/accuracies': 1.0, 'rewards/margins': 1.045740008354187, 'logps/rejected': -34.46910858154297, 'logps/chosen': -40.61585235595703, 'logits/rejected': -11.850056648254395, 'logits/chosen': -11.637435913085938, 'epoch': 0.12}
# {'loss': 0.4804, 'learning_rate': 9.989865272804063e-05, 'rewards/chosen': -0.18795493245124817, 'rewards/rejected': -0.7330539226531982, 'rewards/accuracies': 0.875, 'rewards/margins': 0.5450990200042725, 'logps/rejected': -25.23040771484375, 'logps/chosen': -30.175373077392578, 'logits/rejected': -12.557854652404785, 'logits/chosen': -12.302925109863281, 'epoch': 0.12}
# {'loss': 0.4746, 'learning_rate': 9.988708347786289e-05, 'rewards/chosen': -0.2590760588645935, 'rewards/rejected': -0.8348466157913208, 'rewards/accuracies': 0.875, 'rewards/margins': 0.5757706165313721, 'logps/rejected': -22.31865692138672, 'logps/chosen': -27.95754623413086, 'logits/rejected': -12.035927772521973, 'logits/chosen': -12.142727851867676, 'epoch': 0.12}
# {'loss': 0.3516, 'learning_rate': 9.9874889829725e-05, 'rewards/chosen': -0.16815811395645142, 'rewards/rejected': -1.2357370853424072, 'rewards/accuracies': 1.0, 'rewards/margins': 1.0675790309906006, 'logps/rejected': -29.970203399658203, 'logps/chosen': -40.21851348876953, 'logits/rejected': -12.019782066345215, 'logits/chosen': -12.109118461608887, 'epoch': 0.12}
# {'loss': 0.368, 'learning_rate': 9.986207193624536e-05, 'rewards/chosen': -0.03712395578622818, 'rewards/rejected': -0.9953631162643433, 'rewards/accuracies': 0.9375, 'rewards/margins': 0.9582391381263733, 'logps/rejected': -31.565608978271484, 'logps/chosen': -41.37592697143555, 'logits/rejected': -11.952737808227539, 'logits/chosen': -11.672149658203125, 'epoch': 0.12}
# {'loss': 0.347, 'learning_rate': 9.984862995785564e-05, 'rewards/chosen': -0.06526775658130646, 'rewards/rejected': -1.080269455909729, 'rewards/accuracies': 0.9375, 'rewards/margins': 1.015001654624939, 'logps/rejected': -26.615154266357422, 'logps/chosen': -37.67060089111328, 'logits/rejected': -12.560676574707031, 'logits/chosen': -12.306402206420898, 'epoch': 0.12}
# {'loss': 0.2981, 'learning_rate': 9.983456406279866e-05, 'rewards/chosen': -0.28617292642593384, 'rewards/rejected': -1.5182746648788452, 'rewards/accuracies': 1.0, 'rewards/margins': 1.2321016788482666, 'logps/rejected': -38.13031005859375, 'logps/chosen': -46.35378646850586, 'logits/rejected': -11.643651962280273, 'logits/chosen': -11.563545227050781, 'epoch': 0.12}
# {'loss': 0.3054, 'learning_rate': 9.981987442712633e-05, 'rewards/chosen': -0.17732207477092743, 'rewards/rejected': -1.3776341676712036, 'rewards/accuracies': 1.0, 'rewards/margins': 1.2003121376037598, 'logps/rejected': -35.64213943481445, 'logps/chosen': -50.48031234741211, 'logits/rejected': -12.34245777130127, 'logits/chosen': -12.610771179199219, 'epoch': 0.13}
# {'loss': 0.3956, 'learning_rate': 9.980456123469742e-05, 'rewards/chosen': -0.13104340434074402, 'rewards/rejected': -1.0304914712905884, 'rewards/accuracies': 0.875, 'rewards/margins': 0.899448037147522, 'logps/rejected': -22.182777404785156, 'logps/chosen': -32.12739562988281, 'logits/rejected': -12.121357917785645, 'logits/chosen': -12.089158058166504, 'epoch': 0.13}
# {'loss': 0.4263, 'learning_rate': 9.978862467717532e-05, 'rewards/chosen': -0.3258262872695923, 'rewards/rejected': -1.1304199695587158, 'rewards/accuracies': 0.8125, 'rewards/margins': 0.8045936226844788, 'logps/rejected': -25.434701919555664, 'logps/chosen': -32.099220275878906, 'logits/rejected': -12.22372055053711, 'logits/chosen': -12.342974662780762, 'epoch': 0.13}
# {'loss': 0.4614, 'learning_rate': 9.977206495402554e-05, 'rewards/chosen': -0.4173460006713867, 'rewards/rejected': -1.1468167304992676, 'rewards/accuracies': 0.875, 'rewards/margins': 0.7294707298278809, 'logps/rejected': -27.331329345703125, 'logps/chosen': -38.543766021728516, 'logits/rejected': -12.562045097351074, 'logits/chosen': -12.490060806274414, 'epoch': 0.13}
# {'loss': 0.4267, 'learning_rate': 9.97548822725133e-05, 'rewards/chosen': -0.39305412769317627, 'rewards/rejected': -1.2265465259552002, 'rewards/accuracies': 0.875, 'rewards/margins': 0.8334922790527344, 'logps/rejected': -26.102832794189453, 'logps/chosen': -34.60648727416992, 'logits/rejected': -11.890073776245117, 'logits/chosen': -11.752392768859863, 'epoch': 0.13}
# ...
# {'loss': 0.1446, 'learning_rate': 5.250733142932563e-07, 'rewards/chosen': -9.655457496643066, 'rewards/rejected': -15.5084228515625, 'rewards/accuracies': 0.9375, 'rewards/margins': 5.852964878082275, 'logps/rejected': -170.93069458007812, 'logps/chosen': -129.2755126953125, 'logits/rejected': -27.665193557739258, 'logits/chosen': -27.884902954101562, 'epoch': 0.96}
# {'loss': 0.1628, 'learning_rate': 4.998145789118114e-07, 'rewards/chosen': -8.654512405395508, 'rewards/rejected': -13.896141052246094, 'rewards/accuracies': 0.8125, 'rewards/margins': 5.241629123687744, 'logps/rejected': -161.58355712890625, 'logps/chosen': -121.3005142211914, 'logits/rejected': -26.476238250732422, 'logits/chosen': -26.92002296447754, 'epoch': 0.96}
# {'loss': 0.055, 'learning_rate': 4.7517539898741524e-07, 'rewards/chosen': -7.7879414558410645, 'rewards/rejected': -15.762986183166504, 'rewards/accuracies': 1.0, 'rewards/margins': 7.9750447273254395, 'logps/rejected': -174.43994140625, 'logps/chosen': -119.15813446044922, 'logits/rejected': -26.59734344482422, 'logits/chosen': -26.52565574645996, 'epoch': 0.96}
# {'loss': 0.052, 'learning_rate': 4.511560829095818e-07, 'rewards/chosen': -7.504889488220215, 'rewards/rejected': -15.740270614624023, 'rewards/accuracies': 1.0, 'rewards/margins': 8.235382080078125, 'logps/rejected': -174.98477172851562, 'logps/chosen': -112.41219329833984, 'logits/rejected': -26.8958683013916, 'logits/chosen': -26.5014705657959, 'epoch': 0.96}
# {'loss': 0.1573, 'learning_rate': 4.277569313094809e-07, 'rewards/chosen': -7.7466959953308105, 'rewards/rejected': -14.641302108764648, 'rewards/accuracies': 0.8125, 'rewards/margins': 6.89460563659668, 'logps/rejected': -161.7865447998047, 'logps/chosen': -113.1307373046875, 'logits/rejected': -27.28304672241211, 'logits/chosen': -27.504791259765625, 'epoch': 0.96}
# {'loss': 0.0832, 'learning_rate': 4.049782370561583e-07, 'rewards/chosen': -10.219273567199707, 'rewards/rejected': -18.085107803344727, 'rewards/accuracies': 1.0, 'rewards/margins': 7.8658342361450195, 'logps/rejected': -201.08438110351562, 'logps/chosen': -149.8534698486328, 'logits/rejected': -27.80500602722168, 'logits/chosen': -27.868192672729492, 'epoch': 0.96}
# {'loss': 0.1561, 'learning_rate': 3.8282028525287174e-07, 'rewards/chosen': -9.069436073303223, 'rewards/rejected': -15.824525833129883, 'rewards/accuracies': 0.875, 'rewards/margins': 6.755090713500977, 'logps/rejected': -173.68618774414062, 'logps/chosen': -126.82766723632812, 'logits/rejected': -27.94830894470215, 'logits/chosen': -28.24134063720703, 'epoch': 0.96}
# {'loss': 0.0546, 'learning_rate': 3.61283353233538e-07, 'rewards/chosen': -10.723682403564453, 'rewards/rejected': -19.21379852294922, 'rewards/accuracies': 0.9375, 'rewards/margins': 8.490116119384766, 'logps/rejected': -204.70941162109375, 'logps/chosen': -140.39971923828125, 'logits/rejected': -26.160032272338867, 'logits/chosen': -25.705604553222656, 'epoch': 0.97}
# {'loss': 0.225, 'learning_rate': 3.4036771055923066e-07, 'rewards/chosen': -8.512863159179688, 'rewards/rejected': -14.505698204040527, 'rewards/accuracies': 0.8125, 'rewards/margins': 5.992835998535156, 'logps/rejected': -160.14590454101562, 'logps/chosen': -113.48885345458984, 'logits/rejected': -28.193111419677734, 'logits/chosen': -28.17189598083496, 'epoch': 0.97}
# {'loss': 0.1956, 'learning_rate': 3.2007361901485455e-07, 'rewards/chosen': -9.045286178588867, 'rewards/rejected': -15.870787620544434, 'rewards/accuracies': 0.8125, 'rewards/margins': 6.825501918792725, 'logps/rejected': -181.8847198486328, 'logps/chosen': -130.24026489257812, 'logits/rejected': -26.689332962036133, 'logits/chosen': -26.823915481567383, 'epoch': 0.97}
# {'loss': 0.1032, 'learning_rate': 3.0040133260581525e-07, 'rewards/chosen': -12.1969633102417, 'rewards/rejected': -18.929868698120117, 'rewards/accuracies': 0.9375, 'rewards/margins': 6.732905387878418, 'logps/rejected': -212.2120819091797, 'logps/chosen': -163.614990234375, 'logits/rejected': -27.057119369506836, 'logits/chosen': -27.483570098876953, 'epoch': 0.97}
# {'loss': 0.1552, 'learning_rate': 2.813510975548772e-07, 'rewards/chosen': -8.678104400634766, 'rewards/rejected': -14.596080780029297, 'rewards/accuracies': 0.875, 'rewards/margins': 5.9179768562316895, 'logps/rejected': -161.15280151367188, 'logps/chosen': -119.53945922851562, 'logits/rejected': -28.390029907226562, 'logits/chosen': -28.520212173461914, 'epoch': 0.97}
# {'loss': 0.0857, 'learning_rate': 2.629231522990716e-07, 'rewards/chosen': -8.534440994262695, 'rewards/rejected': -14.71650505065918, 'rewards/accuracies': 1.0, 'rewards/margins': 6.182063579559326, 'logps/rejected': -167.43429565429688, 'logps/chosen': -125.71660614013672, 'logits/rejected': -27.922016143798828, 'logits/chosen': -28.342424392700195, 'epoch': 0.97}
# {'loss': 0.2008, 'learning_rate': 2.451177274866989e-07, 'rewards/chosen': -8.259246826171875, 'rewards/rejected': -15.638922691345215, 'rewards/accuracies': 0.9375, 'rewards/margins': 7.379676818847656, 'logps/rejected': -173.8267822265625, 'logps/chosen': -118.08021545410156, 'logits/rejected': -27.476171493530273, 'logits/chosen': -27.298749923706055, 'epoch': 0.97}
# {'loss': 0.209, 'learning_rate': 2.2793504597447002e-07, 'rewards/chosen': -9.086650848388672, 'rewards/rejected': -15.340808868408203, 'rewards/accuracies': 0.75, 'rewards/margins': 6.254158020019531, 'logps/rejected': -168.63497924804688, 'logps/chosen': -124.99126434326172, 'logits/rejected': -26.58588409423828, 'logits/chosen': -26.473825454711914, 'epoch': 0.97}
# {'loss': 0.2032, 'learning_rate': 2.1137532282469174e-07, 'rewards/chosen': -8.472248077392578, 'rewards/rejected': -15.583351135253906, 'rewards/accuracies': 0.875, 'rewards/margins': 7.11110258102417, 'logps/rejected': -170.31195068359375, 'logps/chosen': -120.44937133789062, 'logits/rejected': -25.7353515625, 'logits/chosen': -25.767650604248047, 'epoch': 0.97}
# {'loss': 0.2105, 'learning_rate': 1.954387653025802e-07, 'rewards/chosen': -8.793638229370117, 'rewards/rejected': -14.370389938354492, 'rewards/accuracies': 0.875, 'rewards/margins': 5.576749801635742, 'logps/rejected': -157.13076782226562, 'logps/chosen': -123.2314453125, 'logits/rejected': -26.86072540283203, 'logits/chosen': -26.535722732543945, 'epoch': 0.97}
# {'loss': 0.1431, 'learning_rate': 1.8012557287367392e-07, 'rewards/chosen': -7.840725898742676, 'rewards/rejected': -15.687081336975098, 'rewards/accuracies': 0.9375, 'rewards/margins': 7.84635591506958, 'logps/rejected': -180.7996368408203, 'logps/chosen': -124.01335144042969, 'logits/rejected': -27.964534759521484, 'logits/chosen': -27.48202896118164, 'epoch': 0.98}
# {'loss': 0.1003, 'learning_rate': 1.6543593720134144e-07, 'rewards/chosen': -9.003950119018555, 'rewards/rejected': -16.339733123779297, 'rewards/accuracies': 0.9375, 'rewards/margins': 7.335782051086426, 'logps/rejected': -179.77418518066406, 'logps/chosen': -124.99966430664062, 'logits/rejected': -26.409914016723633, 'logits/chosen': -26.795265197753906, 'epoch': 0.98}
# {'loss': 0.144, 'learning_rate': 1.513700421443609e-07, 'rewards/chosen': -9.98082160949707, 'rewards/rejected': -18.4281005859375, 'rewards/accuracies': 0.875, 'rewards/margins': 8.447278022766113, 'logps/rejected': -205.25193786621094, 'logps/chosen': -140.94708251953125, 'logits/rejected': -26.947410583496094, 'logits/chosen': -27.205930709838867, 'epoch': 0.98}
# {'loss': 0.1321, 'learning_rate': 1.379280637546443e-07, 'rewards/chosen': -7.152875900268555, 'rewards/rejected': -13.406539916992188, 'rewards/accuracies': 0.9375, 'rewards/margins': 6.253664016723633, 'logps/rejected': -152.57257080078125, 'logps/chosen': -103.51901245117188, 'logits/rejected': -26.650283813476562, 'logits/chosen': -26.417980194091797, 'epoch': 0.98}
# {'loss': 0.0931, 'learning_rate': 1.2511017027501682e-07, 'rewards/chosen': -9.874834060668945, 'rewards/rejected': -16.514522552490234, 'rewards/accuracies': 0.9375, 'rewards/margins': 6.6396894454956055, 'logps/rejected': -181.97116088867188, 'logps/chosen': -135.1822509765625, 'logits/rejected': -27.58968162536621, 'logits/chosen': -27.702756881713867, 'epoch': 0.98}
# {'loss': 0.1793, 'learning_rate': 1.1291652213710757e-07, 'rewards/chosen': -8.534067153930664, 'rewards/rejected': -15.453298568725586, 'rewards/accuracies': 0.9375, 'rewards/margins': 6.919229507446289, 'logps/rejected': -171.05076599121094, 'logps/chosen': -117.53913879394531, 'logits/rejected': -27.965496063232422, 'logits/chosen': -28.341106414794922, 'epoch': 0.98}
# {'loss': 0.1612, 'learning_rate': 1.0134727195937333e-07, 'rewards/chosen': -9.898725509643555, 'rewards/rejected': -15.069674491882324, 'rewards/accuracies': 0.9375, 'rewards/margins': 5.170948028564453, 'logps/rejected': -162.7728729248047, 'logps/chosen': -124.28459930419922, 'logits/rejected': -27.244400024414062, 'logits/chosen': -26.502803802490234, 'epoch': 0.98}
# {'loss': 0.1838, 'learning_rate': 9.040256454514451e-08, 'rewards/chosen': -7.810011863708496, 'rewards/rejected': -14.810606002807617, 'rewards/accuracies': 0.875, 'rewards/margins': 7.000594615936279, 'logps/rejected': -164.7799072265625, 'logps/chosen': -111.91276550292969, 'logits/rejected': -27.471158981323242, 'logits/chosen': -27.192468643188477, 'epoch': 0.98}
# {'loss': 0.2709, 'learning_rate': 8.008253688084889e-08, 'rewards/chosen': -8.168739318847656, 'rewards/rejected': -12.618072509765625, 'rewards/accuracies': 0.8125, 'rewards/margins': 4.449334144592285, 'logps/rejected': -141.0770263671875, 'logps/chosen': -112.54286193847656, 'logits/rejected': -25.55453109741211, 'logits/chosen': -25.493343353271484, 'epoch': 0.98}
# {'loss': 0.1191, 'learning_rate': 7.038731813426291e-08, 'rewards/chosen': -10.08253002166748, 'rewards/rejected': -18.259849548339844, 'rewards/accuracies': 0.9375, 'rewards/margins': 8.17732048034668, 'logps/rejected': -197.89877319335938, 'logps/chosen': -134.08633422851562, 'logits/rejected': -27.840301513671875, 'logits/chosen': -27.553770065307617, 'epoch': 0.98}
# {'loss': 0.0994, 'learning_rate': 6.131702965292974e-08, 'rewards/chosen': -8.458515167236328, 'rewards/rejected': -14.528246879577637, 'rewards/accuracies': 0.9375, 'rewards/margins': 6.06973123550415, 'logps/rejected': -163.19500732421875, 'logps/chosen': -116.76553344726562, 'logits/rejected': -26.954866409301758, 'logits/chosen': -27.23859405517578, 'epoch': 0.99}
# {'loss': 0.0781, 'learning_rate': 5.287178496262701e-08, 'rewards/chosen': -7.770238876342773, 'rewards/rejected': -14.580224990844727, 'rewards/accuracies': 0.9375, 'rewards/margins': 6.809986114501953, 'logps/rejected': -165.82809448242188, 'logps/chosen': -114.03565979003906, 'logits/rejected': -26.953590393066406, 'logits/chosen': -26.99530792236328, 'epoch': 0.99}
# {'loss': 0.2562, 'learning_rate': 4.5051689765929214e-08, 'rewards/chosen': -9.36133098602295, 'rewards/rejected': -12.959315299987793, 'rewards/accuracies': 0.9375, 'rewards/margins': 3.5979840755462646, 'logps/rejected': -143.822021484375, 'logps/chosen': -117.21060180664062, 'logits/rejected': -26.940088272094727, 'logits/chosen': -26.910829544067383, 'epoch': 0.99}
# {'loss': 0.1103, 'learning_rate': 3.785684194090866e-08, 'rewards/chosen': -8.538719177246094, 'rewards/rejected': -16.200275421142578, 'rewards/accuracies': 0.875, 'rewards/margins': 7.661558151245117, 'logps/rejected': -180.8340301513672, 'logps/chosen': -124.19412994384766, 'logits/rejected': -27.441648483276367, 'logits/chosen': -26.889312744140625, 'epoch': 0.99}
# {'loss': 0.1786, 'learning_rate': 3.128733153990315e-08, 'rewards/chosen': -8.997314453125, 'rewards/rejected': -16.279401779174805, 'rewards/accuracies': 0.875, 'rewards/margins': 7.2820868492126465, 'logps/rejected': -177.45782470703125, 'logps/chosen': -123.85846710205078, 'logits/rejected': -26.344684600830078, 'logits/chosen': -27.177474975585938, 'epoch': 0.99}
# {'loss': 0.1096, 'learning_rate': 2.534324078837802e-08, 'rewards/chosen': -8.123043060302734, 'rewards/rejected': -16.05736541748047, 'rewards/accuracies': 0.9375, 'rewards/margins': 7.934323310852051, 'logps/rejected': -180.35263061523438, 'logps/chosen': -122.56343078613281, 'logits/rejected': -27.269237518310547, 'logits/chosen': -27.218032836914062, 'epoch': 0.99}
# {'loss': 0.1549, 'learning_rate': 2.0024644083921352e-08, 'rewards/chosen': -9.537861824035645, 'rewards/rejected': -15.19412612915039, 'rewards/accuracies': 0.9375, 'rewards/margins': 5.656263828277588, 'logps/rejected': -173.2898712158203, 'logps/chosen': -133.9302978515625, 'logits/rejected': -26.99635887145996, 'logits/chosen': -27.363590240478516, 'epoch': 0.99}
# {'loss': 0.2185, 'learning_rate': 1.5331607995267007e-08, 'rewards/chosen': -7.886689186096191, 'rewards/rejected': -13.054397583007812, 'rewards/accuracies': 0.8125, 'rewards/margins': 5.167708873748779, 'logps/rejected': -150.36380004882812, 'logps/chosen': -112.17959594726562, 'logits/rejected': -27.571096420288086, 'logits/chosen': -27.68925666809082, 'epoch': 0.99}
# {'loss': 0.139, 'learning_rate': 1.1264191261528557e-08, 'rewards/chosen': -10.27661418914795, 'rewards/rejected': -16.878679275512695, 'rewards/accuracies': 0.9375, 'rewards/margins': 6.60206413269043, 'logps/rejected': -185.41885375976562, 'logps/chosen': -140.04833984375, 'logits/rejected': -27.670412063598633, 'logits/chosen': -27.18104362487793, 'epoch': 0.99}
# {'loss': 0.0766, 'learning_rate': 7.82244479139993e-09, 'rewards/chosen': -8.052085876464844, 'rewards/rejected': -13.337401390075684, 'rewards/accuracies': 1.0, 'rewards/margins': 5.285315036773682, 'logps/rejected': -145.689453125, 'logps/chosen': -108.27445983886719, 'logits/rejected': -27.06755828857422, 'logits/chosen': -26.654104232788086, 'epoch': 0.99}
# {'loss': 0.094, 'learning_rate': 5.006411662555888e-09, 'rewards/chosen': -9.108604431152344, 'rewards/rejected': -16.453296661376953, 'rewards/accuracies': 1.0, 'rewards/margins': 7.344693183898926, 'logps/rejected': -187.70199584960938, 'logps/chosen': -134.47203063964844, 'logits/rejected': -28.05648422241211, 'logits/chosen': -27.730741500854492, 'epoch': 1.0}
# {'loss': 0.0612, 'learning_rate': 2.8161271211024633e-09, 'rewards/chosen': -10.476306915283203, 'rewards/rejected': -19.268207550048828, 'rewards/accuracies': 0.9375, 'rewards/margins': 8.791900634765625, 'logps/rejected': -209.93482971191406, 'logps/chosen': -149.36883544921875, 'logits/rejected': -26.251007080078125, 'logits/chosen': -26.114349365234375, 'epoch': 1.0}
# {'loss': 0.0809, 'learning_rate': 1.2516185811273228e-09, 'rewards/chosen': -11.243349075317383, 'rewards/rejected': -22.028488159179688, 'rewards/accuracies': 1.0, 'rewards/margins': 10.785139083862305, 'logps/rejected': -240.7645721435547, 'logps/chosen': -160.9991455078125, 'logits/rejected': -28.008424758911133, 'logits/chosen': -27.75994873046875, 'epoch': 1.0}
# {'loss': 0.1078, 'learning_rate': 3.129056243833528e-10, 'rewards/chosen': -8.108412742614746, 'rewards/rejected': -14.719857215881348, 'rewards/accuracies': 0.875, 'rewards/margins': 6.611444473266602, 'logps/rejected': -173.05093383789062, 'logps/chosen': -123.02288818359375, 'logits/rejected': -27.112468719482422, 'logits/chosen': -27.385921478271484, 'epoch': 1.0}
# {'loss': 0.2312, 'learning_rate': 0.0, 'rewards/chosen': -7.199064254760742, 'rewards/rejected': -13.754183769226074, 'rewards/accuracies': 0.8571429252624512, 'rewards/margins': 6.555118083953857, 'logps/rejected': -154.75039672851562, 'logps/chosen': -106.04837799072266, 'logits/rejected': -26.871213912963867, 'logits/chosen': -27.08344841003418, 'epoch': 1.0}
# {'train_runtime': 269.4776, 'train_samples_per_second': 58.654, 'train_steps_per_second': 3.666, 'train_loss': 0.2041456379672241, 'epoch': 1.0}
# TrainOutput(global_step=988, training_loss=0.2041456379672241, metrics={'train_runtime': 269.4776, 'train_samples_per_second': 58.654, 'train_steps_per_second': 3.666, 'train_loss': 0.2041456379672241, 'epoch': 1.0})

# %%
dpo_trainer.model.save_pretrained(f"{model_output_dir}/final_checkpoint")
tokenizer.save_pretrained(f"{model_output_dir}/final_checkpoint")

torch.cuda.empty_cache()

base_model = T5ForConditionalGeneration.from_pretrained(
    model_name,
    return_dict=True,
    torch_dtype=torch.float16,
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

model = PeftModel.from_pretrained(base_model, f"{model_output_dir}/final_checkpoint")
model = model.merge_and_unload()

model.save_pretrained(model_output_dir)
tokenizer.save_pretrained(model_output_dir)
# Out:
# ('dpo_google/flan-t5-small_lora\\tokenizer_config.json',
#  'dpo_google/flan-t5-small_lora\\special_tokens_map.json',
#  'dpo_google/flan-t5-small_lora\\spiece.model',
#  'dpo_google/flan-t5-small_lora\\added_tokens.json',
#  'dpo_google/flan-t5-small_lora\\tokenizer.json')

# %%
def translate_batch(batch, model=model, tokenizer=tokenizer):
    inputTokens = tokenizer(batch, padding=True, return_tensors="pt", truncation=True).to(device)
    outputs = model.generate(input_ids = inputTokens['input_ids'].long(), attention_mask=inputTokens['attention_mask'], max_new_tokens=128)
    outputs = tokenizer.batch_decode(outputs, skip_special_tokens=True)

    for i, j in zip(batch, outputs):
        print(f"prompt: <{i}>, output:{j}")

model.cuda()
translate_batch(df.prompt.values.tolist()[:10])
# Out:
# prompt: <translate English to Romanian: I ate the cheese.>, output:I sam.
# prompt: <translate English to Romanian: Today is Monday.>, output:ksk.
# prompt: <translate English to Romanian: Does he speak English?>, output:samsassa
# prompt: <translate English to Romanian: I'm sort of tired.>, output:iks.
# prompt: <translate English to Romanian: I am indebted to him.>, output:iksk.
# prompt: <translate English to Romanian: He refused to say more about that.>, output:yswa.
# prompt: <translate English to Romanian: Let me in, please.>, output:nk, n.
# prompt: <translate English to Romanian: Spring is around the corner.>, output:Spring sway.
# prompt: <translate English to Romanian: Spring will arrive there soon.>, output:Spring sway.
# prompt: <translate English to Romanian: You don’t need to apply in advance.>, output:nsad.
